# %% [markdown]
# # Libraries

# %%
import requests
import json
import matplotlib.pyplot as plt

# %% [markdown]
# # Get json file from website

# %% [markdown]
# From https://docs.awesomeapi.com.br/api-de-moedas

# %%
currencies = requests.get('https://economia.awesomeapi.com.br/json/all')
currencies_dic = currencies.json()
print(currencies_dic)
# Out:
# {'USD': {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '4.8074', 'low': '4.8072', 'varBid': '0.0005', 'pctChange': '0.01', 'bid': '4.8069', 'ask': '4.8074', 'timestamp': '1689627602', 'create_date': '2023-07-17 18:00:02'}, 'USDT': {'code': 'USD', 'codein': 'BRLT', 'name': 'Dólar Americano/Real Brasileiro Turismo', 'high': '4.835', 'low': '4.835', 'varBid': '0', 'pctChange': '0', 'bid': '4.69', 'ask': '4.98', 'timestamp': '1689619980', 'create_date': '2023-07-17 15:53:00'}, 'CAD': {'code': 'CAD', 'codein': 'BRL', 'name': 'Dólar Canadense/Real Brasileiro', 'high': '3.6433', 'low': '3.6418', 'varBid': '-0.0014', 'pctChange': '-0.04', 'bid': '3.6392', 'ask': '3.6446', 'timestamp': '1689637426', 'create_date': '2023-07-17 20:43:46'}, 'GBP': {'code': 'GBP', 'codein': 'BRL', 'name': 'Libra Esterlina/Real Brasileiro', 'high': '6.2893', 'low': '6.2814', 'varBid': '-0.004', 'pctChange': '-0.06', 'bid': '6.2775', 'ask': '6.2933', 'timestamp': '1689637411', 'create_date': '2023-07-17 20:43:31'}, 'ARS': {'code': 'ARS', 'codein': 'BRL', 'name': 'Peso Argentino/Real Brasileiro', 'high': '0.018', 'low': '0.018', 'varBid': '0', 'pctChange': '0', 'bid': '0.018', 'ask': '0.018', 'timestamp': '1689637417', 'create_date': '2023-07-17 20:43:37'}, 'BTC': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '147460', 'low': '144000', 'varBid': '-425', 'pctChange': '-0.29', 'bid': '145546', 'ask': '145554', 'timestamp': '1689637442', 'create_date': '2023-07-17 20:44:02'}, 'LTC': {'code': 'LTC', 'codein': 'BRL', 'name': 'Litecoin/Real Brasileiro', 'high': '468', 'low': '429.69', 'varBid': '-4.34', 'pctChange': '-0.96', 'bid': '445.22', 'ask': '446.13', 'timestamp': '1689637439', 'create_date': '2023-07-17 20:43:59'}, 'EUR': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '5.4047', 'low': '5.4016', 'varBid': '-0.0019', 'pctChange': '-0.04', 'bid': '5.3988', 'ask': '5.4068', 'timestamp': '1689637417', 'create_date': '2023-07-17 20:43:37'}, 'JPY': {'code': 'JPY', 'codein': 'BRL', 'name': 'Iene Japonês/Real Brasileiro', 'high': '0.03467', 'low': '0.03465', 'varBid': '0', 'pctChange': '0', 'bid': '0.03465', 'ask': '0.03467', 'timestamp': '1689637442', 'create_date': '2023-07-17 20:44:02'}, 'CHF': {'code': 'CHF', 'codein': 'BRL', 'name': 'Franco Suíço/Real Brasileiro', 'high': '5.5903', 'low': '5.5851', 'varBid': '-0.0032', 'pctChange': '-0.06', 'bid': '5.583', 'ask': '5.5912', 'timestamp': '1689637426', 'create_date': '2023-07-17 20:43:46'}, 'AUD': {'code': 'AUD', 'codein': 'BRL', 'name': 'Dólar Australiano/Real Brasileiro', 'high': '3.2794', 'low': '3.276', 'varBid': '-0.0021', 'pctChange': '-0.06', 'bid': '3.2735', 'ask': '3.2784', 'timestamp': '1689637417', 'create_date': '2023-07-17 20:43:37'}, 'CNY': {'code': 'CNY', 'codein': 'BRL', 'name': 'Yuan Chinês/Real Brasileiro', 'high': '0.6757', 'low': '0.6673', 'varBid': '-0.0004', 'pctChange': '-0.06', 'bid': '0.6703', 'ask': '0.6703', 'timestamp': '1689633122', 'create_date': '2023-07-17 19:32:02'}, 'ILS': {'code': 'ILS', 'codein': 'BRL', 'name': 'Novo Shekel Israelense/Real Brasileiro', 'high': '1.3335', 'low': '1.3154', 'varBid': '-0.0047', 'pctChange': '-0.36', 'bid': '1.3232', 'ask': '1.3234', 'timestamp': '1689635464', 'create_date': '2023-07-17 20:11:04'}, 'ETH': {'code': 'ETH', 'codein': 'BRL', 'name': 'Ethereum/Real Brasileiro', 'high': '9342.06', 'low': '9070.01', 'varBid': '-44.62', 'pctChange': '-0.48', 'bid': '9223.93', 'ask': '9266.46', 'timestamp': '1689637439', 'create_date': '2023-07-17 20:43:59'}, 'XRP': {'code': 'XRP', 'codein': 'BRL', 'name': 'XRP/Real Brasileiro', 'high': '3.71', 'low': '3.4', 'varBid': '-0.03', 'pctChange': '-0.94', 'bid': '3.56', 'ask': '3.57', 'timestamp': '1689637442', 'create_date': '2023-07-17 20:44:02'}, 'DOGE': {'code': 'DOGE', 'codein': 'BRL', 'name': 'Dogecoin/Real Brasileiro', 'high': '0.3478', 'low': '0.3294', 'varBid': '0.00291', 'pctChange': '0.87', 'bid': '0.33622', 'ask' ...

# %%
print('Moeda: {}\nValor: {}'.format(currencies_dic['USD']['code'], currencies_dic['USD']['bid']))
# Out:
# Moeda: USD
# Valor: 4.8069

# %% [markdown]
# # Exploring last 180 days

# %%
days = '/180'
currency = '/USD-BRL'
currencies_days = requests.get('https://economia.awesomeapi.com.br/json/daily/'+currency+days)
currencies_dic_days = currencies_days.json()
print(currencies_dic_days[:2])
# Out:
# [{'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '4.7896', 'low': '4.7896', 'varBid': '0', 'pctChange': '0', 'bid': '4.7889', 'ask': '4.7903', 'timestamp': '1689534395', 'create_date': '2023-07-16 16:06:35'}, {'high': '4.8148', 'low': '4.776', 'varBid': '0.0002', 'pctChange': '0', 'bid': '4.7889', 'ask': '4.7903', 'timestamp': '1689534395'}]

# %%
last_days_list = [float(item['bid']) for item in currencies_dic_days]
last_days_list.reverse()

# %% [markdown]
# # Plot data

# %%
plt.figure(figsize = (15,5))
plt.plot(last_days_list)
plt.show()

# %% [markdown]
# # Python e API com Login
# https://www.twilio.com/docs/libraries/python

# %%
from twilio.rest import Client

account_sid = 'AC5a23fb4df8af82b8092ef97b0e34effa'
token = 'e60f36ab07adabf03a58319a26df9f9f'

client = Client(account_sid, token)

sender = '+18064194961' # twilio number
destiny = '+5521972795556'

message = client.messages.create(
    to=destino, 
    from_=remetente,
    body="Hello, SMS world!")

print(message.sid)
# Out:
# SMdcd54d6233307927f8a78b0354930560
